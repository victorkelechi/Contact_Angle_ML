# %%
import pandas as pd
import requests

# Read your CSV
data = pd.read_csv("Test.csv")

# Convert to JSON
data_json = data.to_dict(orient="records")

# Send request
url = "http://127.0.0.1:9696/predict"
response = requests.post(url, json=data_json)

# Get predictions from response
predictions = response.json()["predictions"]

# Combine into a DataFrame
result = pd.DataFrame({"id":data.index,
                       "predicted_contact_angle":predictions})

result.head()
# Out:
#    id  predicted_contact_angle
# 0   0                32.185310
# 1   1                33.014593
# 2   2                32.660225
# 3   3                37.000987
# 4   4                38.087330
